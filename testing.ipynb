# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import time

path= "chromedriver.exe"  
driver=webdriver.Chrome(service=Service(path)) 
driver.get('http://127.0.0.1:8000/')
driver.set_window_size(1120, 1000)
print("Test Passed")
print(driver.title)


time.sleep(2)
driver.close()
# Out:
# Test Passed
# Bike Buy and Sell

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service  
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time

path= "chromedriver.exe"
driver=webdriver.Chrome(service=Service(path)) 
driver.get('http://127.0.0.1:8000/')
driver.set_window_size(1120, 1000)


driver.find_element(By.LINK_TEXT, "Home").click() 
time.sleep(2)

driver.find_element(By.LINK_TEXT, "Buy").click()  
time.sleep(2)

driver.find_element(By.LINK_TEXT, "Bike Buy and Sell").click()  
time.sleep(2)

image = driver.find_element(By.XPATH, "//img[@alt='Image']")
if image.is_displayed():
    print("Image is displayed.")
time.sleep(2)

driver.close()
# Out:
# Image is displayed.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service  
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time

path= "chromedriver.exe"
driver=webdriver.Chrome(service=Service(path)) 
driver.get('http://127.0.0.1:8000/')
driver.set_window_size(1120, 1000)

driver.find_element(By.LINK_TEXT, "Admin").click()  
time.sleep(2)
driver.close()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service  
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time

path= "chromedriver.exe"
driver=webdriver.Chrome(service=Service(path)) 
driver.get('http://127.0.0.1:8000/registration/')
driver.set_window_size(1120, 1000)

driver.find_element(By.LINK_TEXT, "Sign Up").click()  
time.sleep(2)

driver.find_element(By.NAME, "username").click()
driver.find_element(By.NAME, "username").send_keys("abcd")

time.sleep(2)

driver.find_element(By.NAME, "password1").click()
driver.find_element(By.NAME, "password1").send_keys("abcd.1234")

time.sleep(2)

driver.find_element(By.NAME, "password2").click()
driver.find_element(By.NAME, "password2").send_keys("abcd.1234")

time.sleep(2)



button = driver.find_element(By.CSS_SELECTOR, "input[type='submit']")
button.click()
time.sleep(2)

driver.close()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service  
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time

path= "chromedriver.exe"
driver=webdriver.Chrome(service=Service(path)) 
driver.get('http://127.0.0.1:8000/')
driver.set_window_size(1120, 1000)

driver.find_element(By.LINK_TEXT, "Login").click()  
time.sleep(2)

driver.find_element(By.NAME, "username").click()
driver.find_element(By.NAME, "username").send_keys("abcd")
time.sleep(2)

driver.find_element(By.NAME, "password").click()
driver.find_element(By.NAME, "password").send_keys("abcd.1234")

time.sleep(2)

button = driver.find_element(By.CSS_SELECTOR, "input[type='submit']")
button.click()

driver.close()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service  
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time

path= "chromedriver.exe"
driver=webdriver.Chrome(service=Service(path)) 
driver.get('http://127.0.0.1:8000/login')
driver.set_window_size(1120, 1000)

driver.find_element(By.NAME, "username").click()
driver.find_element(By.NAME, "username").send_keys("abcd")

driver.find_element(By.NAME, "password").click()
driver.find_element(By.NAME, "password").send_keys("abcd.1234")


button = driver.find_element(By.CSS_SELECTOR, "input[type='submit']")
button.click()
time.sleep(2)


driver.find_element(By.LINK_TEXT, "Sports").click() 
time.sleep(2)

driver.close()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service  
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time

path= "chromedriver.exe"
driver=webdriver.Chrome(service=Service(path)) 
driver.get('http://127.0.0.1:8000/login')
driver.set_window_size(1120, 1000)

driver.find_element(By.NAME, "username").click()
driver.find_element(By.NAME, "username").send_keys("abcd")

driver.find_element(By.NAME, "password").click()
driver.find_element(By.NAME, "password").send_keys("abcd.1234")


button = driver.find_element(By.CSS_SELECTOR, "input[type='submit']")
button.click()
time.sleep(2)


driver.find_element(By.LINK_TEXT, "Racing Bike").click() 
time.sleep(2)

search_box = driver.find_element(By.NAME, "query")
search_box.send_keys("New Honda CBR 150R")
time.sleep(2)

submit_button = driver.find_element(By.ID, "search")  
submit_button.click()
time.sleep(2)

driver.find_element(By.LINK_TEXT, "New Honda CBR 150R").click() 
time.sleep(2)

submit_button = driver.find_element(By.ID, "addtocart")  
submit_button.click()
time.sleep(2)

driver.find_element(By.ID, "id_quantity").click()
dropdown = driver.find_element(By.ID, "id_quantity")
dropdown.find_element('xpath', '//*[@id="id_quantity"]/option[2]').click()
time.sleep(2)

submit_button = driver.find_element(By.ID, "updated")  
submit_button.click()
time.sleep(2)

driver.find_element(By.LINK_TEXT, "Checkout").click() 
time.sleep(2)

email_field = driver.find_element(By.ID, "id_email")  
email_field.clear()

# Test valid email input
valid_email = "test@example.com"
email_field.send_keys(valid_email)

driver.find_element(By.NAME, "mobile")
driver.find_element(By.NAME, "mobile").send_keys("01111111111")
time.sleep(2)

driver.find_element(By.NAME, "address")
driver.find_element(By.NAME, "address").send_keys("dhaka")
time.sleep(2)

submit_button = driver.find_element(By.ID, "adresssubmit")  
submit_button.click()
time.sleep(2)

driver.close()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service  
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time

path= "chromedriver.exe"
driver=webdriver.Chrome(service=Service(path)) 
driver.get('http://127.0.0.1:8000/sell')
driver.set_window_size(1120, 1000)

driver.find_element(By.NAME, "username").click()
driver.find_element(By.NAME, "username").send_keys("abcd")

driver.find_element(By.NAME, "password").click()
driver.find_element(By.NAME, "password").send_keys("abcd.1234")


button = driver.find_element(By.CSS_SELECTOR, "input[type='submit']")
button.click()


driver.find_element(By.LINK_TEXT, "Bike Sell").click()  
time.sleep(2)

driver.find_element(By.NAME, "name").click()
driver.find_element(By.NAME, "name").send_keys("abcd")
time.sleep(2)

driver.find_element(By.NAME, "description").click()
driver.find_element(By.NAME, "description").send_keys("abcd1234")
time.sleep(2)

driver.find_element(By.NAME, "price").click()
driver.find_element(By.NAME, "price").send_keys("10000")
time.sleep(2)
driver.find_element(By.NAME, "quantity").click()
driver.find_element(By.NAME, "quantity").send_keys("1")
time.sleep(2)

driver.find_element(By.ID, "id_category").click()
dropdown = driver.find_element(By.ID, "id_category")
dropdown.find_element('xpath', '//*[@id="id_category"]/option[2]').click()
time.sleep(2)

upload_element = driver.find_element(By.ID, "id_image") 
upload_element.send_keys("C:/Users/pc/home.png")  

submit_button = driver.find_element(By.ID, "sell")  # Replace with your button's ID
submit_button.click()
time.sleep(2)

driver.close()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service  
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time

path= "chromedriver.exe"
driver=webdriver.Chrome(service=Service(path)) 
driver.get('http://127.0.0.1:8000/sell_list')
driver.set_window_size(1120, 1000)

driver.find_element(By.NAME, "username").click()
driver.find_element(By.NAME, "username").send_keys("abcd")

driver.find_element(By.NAME, "password").click()
driver.find_element(By.NAME, "password").send_keys("abcd.1234")


button = driver.find_element(By.CSS_SELECTOR, "input[type='submit']")
button.click()

driver.find_element(By.LINK_TEXT, "Bike Sell List").click()  
time.sleep(2)

print(driver.current_url)

driver.close()
# Out:
# http://127.0.0.1:8000/sell_list

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service  
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time

path= "chromedriver.exe"
driver=webdriver.Chrome(service=Service(path)) 
driver.get('http://127.0.0.1:8000/booking_list/')
driver.set_window_size(1120, 1000)

driver.find_element(By.NAME, "username").click()
driver.find_element(By.NAME, "username").send_keys("abcd")

driver.find_element(By.NAME, "password").click()
driver.find_element(By.NAME, "password").send_keys("abcd.1234")


button = driver.find_element(By.CSS_SELECTOR, "input[type='submit']")
button.click()

driver.find_element(By.LINK_TEXT, "Booking List").click()  
time.sleep(2)

driver.find_element(By.LINK_TEXT, "Details").click()  
time.sleep(2)

driver.close()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service  
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time

path= "chromedriver.exe"
driver=webdriver.Chrome(service=Service(path)) 
driver.get('http://127.0.0.1:8000/profile/')
driver.set_window_size(1120, 1000)

driver.find_element(By.NAME, "username").click()
driver.find_element(By.NAME, "username").send_keys("abcd")

driver.find_element(By.NAME, "password").click()
driver.find_element(By.NAME, "password").send_keys("abcd.1234")


button = driver.find_element(By.CSS_SELECTOR, "input[type='submit']")
button.click()

driver.find_element(By.LINK_TEXT, "Profile").click()  
time.sleep(2)


driver.find_element(By.LINK_TEXT, "Update").click()  
time.sleep(2)


driver.find_element(By.NAME, "first_name").click()
driver.find_element(By.NAME, "first_name").send_keys("abcd")
time.sleep(2)

driver.find_element(By.NAME, "last_name").click()
driver.find_element(By.NAME, "last_name").send_keys("efgh")
time.sleep(2)

driver.find_element(By.NAME, "email").click()
driver.find_element(By.NAME, "email").send_keys("abcd@gmail.com")
time.sleep(2)

button = driver.find_element(By.CSS_SELECTOR, "input[type='submit']")
button.click()
time.sleep(2)

driver.close()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service  
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time

path= "chromedriver.exe"
driver=webdriver.Chrome(service=Service(path)) 
driver.get('http://127.0.0.1:8000/change-password/')
driver.set_window_size(1120, 1000)

driver.find_element(By.NAME, "username").click()
driver.find_element(By.NAME, "username").send_keys("abcd")

driver.find_element(By.NAME, "password").click()
driver.find_element(By.NAME, "password").send_keys("abcd.1234")


button = driver.find_element(By.CSS_SELECTOR, "input[type='submit']")
button.click()
time.sleep(2)

driver.find_element(By.LINK_TEXT, "Password Change").click()  
time.sleep(2)


driver.find_element(By.NAME, "old_password").click()
driver.find_element(By.NAME, "old_password").send_keys("11111")
time.sleep(2)

driver.find_element(By.NAME, "new_password1").click()
driver.find_element(By.NAME, "new_password1").send_keys("11111")
time.sleep(2)

driver.find_element(By.NAME, "new_password2").click()
driver.find_element(By.NAME, "new_password2").send_keys("11111")
time.sleep(2)


button = driver.find_element(By.CSS_SELECTOR, "input[type='submit']")
button.click()
time.sleep(2)

driver.close()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service  
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time

path= "chromedriver.exe"
driver=webdriver.Chrome(service=Service(path)) 
driver.get('http://127.0.0.1:8000/logout/')
driver.set_window_size(1120, 1000)

driver.find_element(By.NAME, "username").click()
driver.find_element(By.NAME, "username").send_keys("abcd")

driver.find_element(By.NAME, "password").click()
driver.find_element(By.NAME, "password").send_keys("abcd.1234")


button = driver.find_element(By.CSS_SELECTOR, "input[type='submit']")
button.click()
time.sleep(2)

driver.find_element(By.LINK_TEXT, "Logout").click()  
time.sleep(2)

driver.close()
